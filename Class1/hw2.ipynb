# %% [markdown]
# Homework02

# %%
import pandas as pd
import numpy as np

#pd.set_option('display.max_columns', 100)
#pd.set_option('display.max_rows', 500)
df=pd.read_csv('loans_income.csv')
df
# Out:
#             x
# 0       67000
# 1       52000
# 2      100000
# 3       78762
# 4       37041
# ...       ...
# 49995   40000
# 49996   54000
# 49997   50000
# 49998   82000
# 49999   70000
#
# [50000 rows x 1 columns]

# %%
np.random.choice(df['x'],replace=False, size=1000)
# Out:
# array([125000,  50000,  78000, 110000,  75000,  66283, 110000,  57800,
#         49380,  30000, 104000,  40000,  50000,  50000,  78000,  48082,
#         70000, 175000, 100000,  94800, 180000, 110000, 133000,  85000,
#         72000,  85000,  43000, 120108,  45000,  46000,  60000,  48000,
#         68000,  55000,  22800,  30000,  60000,  75000,  25000, 150000,
#         38000,  45000,  58666,  34000,  90000,  65000,  37000, 102000,
#         64000,  65000,  56000,  57000,  54879,  27000,  48000,  80000,
#         80000,  45000,  36000, 120000,  54000,  90000,  80000,  42000,
#         19000,  50000,  52000,  85000, 110000,  75000,  70000,  49800,
#         48000, 120000,  75000,  90000,  40000,  37000, 110000,  68000,
#         48000,  50000, 144000,  65000,  39960,  95000,  35000,  40000,
#        105000, 190000,  56000,  63000,  32500,  68000,  46000,  40000,
#         75000,  60000,  93000, 118000, 140000,  86000,  67511,  42000,
# ...

# %%
np.random.choice(df['x'],replace=True, size=10)
# Out:
# array([ 82000,  66600,  20000,  32000,  65500, 125000,  46875,  65000,
#         85000,  50000], dtype=int64)

# %%
list1=[]
for i in range(1,11):
    list1.append(list(np.random.choice(df['x'],replace=True, size=10)))
list1
# Out:
# [[55000, 50000, 56000, 130000, 100000, 115000, 72000, 30159, 48554, 44000],
#  [40000, 107000, 70000, 57465, 48000, 70000, 72000, 60000, 40000, 60000],
#  [41000, 40000, 65000, 58000, 108000, 63000, 50000, 63000, 35000, 37000],
#  [83604, 44000, 60000, 30000, 117700, 49628, 15024, 63000, 65000, 81000],
#  [60000, 73500, 96000, 55000, 70575, 60000, 105000, 70000, 72000, 46000],
#  [54000, 26000, 95000, 140000, 96000, 60000, 120000, 109000, 55000, 78500],
#  [61000, 38700, 110676, 135000, 35000, 85000, 33000, 32000, 54000, 115000],
#  [25000, 118000, 34000, 47000, 70000, 77000, 75000, 85000, 28536, 54000],
#  [102714, 45000, 50000, 55000, 21000, 50000, 80000, 38000, 195000, 32000],
#  [88000, 42000, 50000, 118044, 98000, 60000, 83199, 100000, 51000, 65000]]

# %%
list2=[]
for i in range(1,101):
    list2.append(list(np.random.choice(df['x'],replace=True, size=10)))
list2
# Out:
# [[50000, 16000, 110000, 55000, 42000, 120000, 50000, 45000, 46000, 45000],
#  [45684, 90840, 22500, 72000, 70000, 70000, 69500, 106000, 36000, 29000],
#  [58000, 65000, 150000, 75000, 80000, 76000, 50000, 37000, 80000, 56000],
#  [98600, 18200, 72000, 120000, 65000, 25000, 40000, 94500, 50000, 140000],
#  [75000, 60000, 101000, 85000, 47000, 63000, 50000, 36000, 120000, 32000],
#  [60000, 83000, 84000, 70000, 45700, 150000, 85000, 97000, 101837, 103000],
#  [168000, 50000, 55000, 36000, 65000, 73000, 103000, 95000, 100000, 60000],
#  [49000, 63000, 56000, 54000, 55000, 84000, 150000, 100000, 53000, 110000],
#  [65440, 75000, 105000, 65000, 78425, 40000, 90000, 87500, 145000, 42000],
#  [45000, 106000, 40000, 42000, 46000, 54000, 85000, 30000, 26000, 63800],
#  [54115, 46000, 120000, 35000, 74000, 32000, 37400, 193000, 100000, 30000],
#  [46000, 175000, 50000, 60000, 105000, 60000, 50000, 150000, 29200, 65000],
# ...

# %%
list3=[]
for i in range(1,1001):
    list3.append(list(np.random.choice(df['x'],replace=True, size=10)))
list3
# Out:
# []

# %%
list4=[]
for i in range(1,11):
    list4.append(list(np.random.choice(df['x'],replace=True, size=100)))
list4
# Out:
# []

# %%
list5=[]
for i in range(1,11):
    list5.append(list(np.random.choice(df['x'],replace=True, size=100)))
list5
# Out:
# [[85000,
#   69000,
#   90000,
#   60000,
#   45000,
#   48000,
#   50000,
#   100000,
#   85000,
#   50000,
#   92000,
#   78300,
#   80000,
#   22668,
#   100156,
#   33280,
#   125000,
#   44000,
#   100000,
#   55000,
#   40000,
#   60500,
#   53000,
#   55000,
#   72000,
#   60000,
#   35000,
#   72000,
#   75000,
#   36000,
#   85000,
#   54000,
#   48000,
#   130000,
#   65700,
#   55000,
#   60000,
#   80000,
#   75000,
#   37000,
#   160000,
#   160000,
#   95000,
#   85000,
#   100000,
#   39893,
#   120000,
#   90000,
#   76000,
#   33975,
#   48000,
#   72090,
#   45000,
#   40000,
#   47694,
#   60000,
#   65000,
#   100000,
#   38862,
#   85000,
#   77000,
#   77744,
#   87106,
#   62000,
#   99976,
#   60000,
#   30000,
#   105000,
#   72000,
#   117500,
#   50000,
#   60000,
#   65000,
#   75000,
#   95000,
#   43000,
#   88000,
#   105000,
#   52000,
#   35000,
#   45000,
#   9600,
#   37000,
#   66560,
#   75000,
#   30000,
#   35000,
#   82500,
#   38000,
# ...
